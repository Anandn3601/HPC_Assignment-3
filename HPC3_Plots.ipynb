# %% [markdown]
# <a href="https://colab.research.google.com/github/Anandn3601/HPC_Assignment-3/blob/main/HPC3_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data
num_threads = [1, 1, 1, 2, 2, 2, 4, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10, 10, 12, 12, 12, 14, 14, 14, 16, 16, 16]
configurations = ['0C-0I-50D', '50C-25I-25D', '100C-0I-0D'] * 9
throughput = [
    0.058823529411764705, 0.0568785185513917, 0.052631578947368425, 0.11764705882352941, 0.11764705882352941, 0.11764705882352941,
    0.22222222222222224, 0.2, 0.22222222222222224, 0.3157894736842105, 0.2608695652173913, 0.3, 0.380952380952381,
    0.3636363636363636, 0.3333333333333333, 0.47619047619047616, 0.4347826086956522, 0.4166666666666667, 0.22222222222222224,
    0.3076923076923077, 0.4, 0.358974358974359, 0.4666666666666667, 0.2641509433962264, 0.3076923076923077,
    0.6956521739130436, 0.6666666666666666
]

# Create a dictionary to store configurations and corresponding colors
config_colors = {'0C-0I-50D': 'blue', '50C-25I-25D': 'orange', '100C-0I-0D': 'green'}

# Plotting
plt.figure(figsize=(10, 6))

for config in set(configurations):
    x_data = [num_threads[i] for i in range(len(num_threads)) if configurations[i] == config]
    y_data = [throughput[i] for i in range(len(throughput)) if configurations[i] == config]
    plt.plot(x_data, y_data, marker='o', label=config, color=config_colors[config], linestyle='-')

plt.title('TAS LOCK')
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.legend(title='Configuration')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
num_threads = [1, 2, 4, 6, 8, 10, 12, 14, 16] * 3
operations = [1000] * 9 + [2000] * 9 + [4000] * 9
configurations = ['0C-0I-50D'] * 9 + ['50C-25I-25D'] * 9 + ['100C-0I-0D'] * 9
throughput = [
    0.0294, 0.0588, 0.1053, 0.1714, 0.2, 0.2439, 0.3077, 0.3889, 0.381,
    0.0313, 0.0714, 0.1176, 0.1765, 0.2105, 0.2564, 0.3333, 0.3415, 0.3721,
    0.0313, 0.0606, 0.1176, 0.1714, 0.2222, 0.2703, 0.3333, 0.3684, 0.4
]

# Create a dictionary to store configurations and corresponding colors
config_colors = {'0C-0I-50D': 'blue', '50C-25I-25D': 'orange', '100C-0I-0D': 'green'}

# Plotting
plt.figure(figsize=(10, 6))

for config in set(configurations):
    x_data = [num_threads[i] for i in range(len(num_threads)) if configurations[i] == config]
    y_data = [throughput[i] for i in range(len(throughput)) if configurations[i] == config]
    plt.plot(x_data, y_data, marker='o', label=config, color=config_colors[config], linestyle='-')

plt.title('TTAS LOCK')
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.legend(title='Configuration')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
num_threads = [1, 1, 1, 2, 2, 1, 2, 2, 2, 4, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10, 10, 12, 12, 12, 14, 14, 14, 16, 16, 16]
operations = [1000, 1000, 1000, 2000, 2000, 1000, 2000, 2000, 2000, 4000, 4000, 4000, 6000, 6000, 6000, 8000, 8000, 8000,
              10000, 10000, 10000, 12000, 12000, 12000, 14000, 14000, 14000, 16000, 16000, 16000]
configurations = ['0C-0I-50D', '50C-25I-25D', '100C-0I-0D'] * 10
throughput = [
    0.0179, 0.0167, 0.0161, 0.0351, 0.0317, 0.0164, 0.0357, 0.0317, 0.0164, 0.0615, 0.069, 0.0597, 0.0923, 0.0984, 0.087,
    0.1194, 0.1176, 0.1159, 0.1471, 0.1471, 0.1408, 0.1875, 0.1765, 0.2, 0.1892, 0.1972, 0.2029, 0.2388, 0.2051, 0.2192
]

# Create a dictionary to store configurations and corresponding colors
config_colors = {'0C-0I-50D': 'blue', '50C-25I-25D': 'orange', '100C-0I-0D': 'green'}

# Plotting
plt.figure(figsize=(10, 6))

for config in set(configurations):
    x_data = [num_threads[i] for i in range(len(num_threads)) if configurations[i] == config]
    y_data = [throughput[i] for i in range(len(throughput)) if configurations[i] == config]
    plt.plot(x_data, y_data, marker='o', label=config, color=config_colors[config], linestyle='-')

plt.title('TTAS LOCK WITH BACKOFF')
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.legend(title='Configuration')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
num_threads = [1, 1, 1, 2, 2, 2, 4, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10, 10, 12, 12, 12, 14, 14, 14, 16, 16, 16]
operations = [1000, 1000, 1000, 2000, 2000, 2000, 4000, 4000, 4000, 6000, 6000, 6000, 8000, 8000, 8000, 10000, 10000, 10000,
              12000, 12000, 12000, 14000, 14000, 14000, 16000, 16000, 16000]
configurations = ['0C-0I-50D', '50C-25I-25D', '100C-0I-0D'] * 9
throughput = [
    0.0714, 0.0625, 0.0769, 0.1111, 0.125, 0.1176, 0.2105, 0.2105, 0.2353, 0.3158, 0.2857, 0.3, 0.4, 0.3636, 0.3636,
    0.4545, 0.4167, 0.4167, 0.48, 0.48, 0.4286, 0.5833, 0.5385, 0.5, 0.6667, 0.6154, 0.5333
]

# Create a dictionary to store configurations and corresponding colors
config_colors = {'0C-0I-50D': 'blue', '50C-25I-25D': 'orange', '100C-0I-0D': 'green'}

# Plotting
plt.figure(figsize=(10, 6))

for config in set(configurations):
    x_data = [num_threads[i] for i in range(len(num_threads)) if configurations[i] == config]
    y_data = [throughput[i] for i in range(len(throughput)) if configurations[i] == config]
    plt.plot(x_data, y_data, marker='o', label=config, color=config_colors[config], linestyle='-')

plt.title('A LOCK')
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.legend(title='Configuration')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
num_threads = [1, 2, 4, 6, 8, 10, 12, 14, 16] * 3
operations = [1000] * 9 + [2000] * 9 + [4000] * 9
configurations = ['0C-0I-50D'] * 9 + ['50C-25I-25D'] * 9 + ['100C-0I-0D'] * 9
throughput = [
    0.125, 0.25, 0.4, 0.6666666666666666, 0.888888888888889, 1.0, 1.0, 1.2727272727272727, 1.4545454545454544,
    0.125, 0.25, 0.4444444444444445, 0.5454545454545455, 0.6666666666666666, 0.8333333333333334, 1.0, 1.1666666666666667, 1.2307692307692308,
    0.14285714285714288, 0.25, 0.4444444444444445, 0.5454545454545455, 0.7272727272727272, 0.8333333333333334, 1.0, 0.9333333333333333, 1.6
]

# Create a dictionary to store configurations and corresponding colors
config_colors = {'0C-0I-50D': 'blue', '50C-25I-25D': 'orange', '100C-0I-0D': 'green'}

# Plotting
plt.figure(figsize=(10, 6))

for config in set(configurations):
    x_data = [num_threads[i] for i in range(len(num_threads)) if configurations[i] == config]
    y_data = [throughput[i] for i in range(len(throughput)) if configurations[i] == config]
    plt.plot(x_data, y_data, marker='o', label=config, color=config_colors[config], linestyle='-')

plt.title('CLH LOCK')
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.legend(title='Configuration')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
num_threads = [1, 1, 1, 2, 2, 2, 4, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10, 10, 12, 12, 12, 14, 14, 14, 16, 16, 16]
operations = [1000, 1000, 1000, 2000, 2000, 2000, 4000, 4000, 4000, 6000, 6000, 6000, 8000, 8000, 8000, 10000, 10000, 10000,
              12000, 12000, 12000, 14000, 14000, 14000, 16000, 16000, 16000]
configurations = ['0C-0I-50D', '50C-25I-25D', '100C-0I-0D'] * 9
throughput = [
    0.0588, 0.04, 0.0588, 0.1176, 0.1053, 0.1111, 0.2222, 0.2105, 0.2353, 0.3158, 0.2857, 0.4222, 0.3636, 0.381, 0.381,
    0.4762, 0.4545, 0.3333, 0.5455, 0.4264, 0.2727, 0.5833, 0.56, 0.3684, 0.5517, 0.5161, 0.7273
]

# Create a dictionary to store configurations and corresponding colors
config_colors = {'0C-0I-50D': 'blue', '50C-25I-25D': 'orange', '100C-0I-0D': 'green'}

# Plotting
plt.figure(figsize=(10, 6))

for config in set(configurations):
    x_data = [num_threads[i] for i in range(len(num_threads)) if configurations[i] == config]
    y_data = [throughput[i] for i in range(len(throughput)) if configurations[i] == config]
    plt.plot(x_data, y_data, marker='o', label=config, color=config_colors[config], linestyle='-')

plt.title('MCS LOCK')
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.legend(title='Configuration')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()
